# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/PostDocProject/keras-gcn/'
# !python setup.py install
from __future__ import print_function
import tensorflow
import keras
from keras.layers import Input, Dropout, Embedding, Dense, Conv1D, GlobalMaxPooling1D, Reshape, Lambda, Concatenate, LayerNormalization, Add
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
import scipy
from scipy import io
import kegra
from kegra.layers.graph import GraphConvolution
from kegra.utils import *
import time
import tensorflow as tf
from config import *
support=1
print(keras.__version__)
print(tf.__version__)
# !python --version
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/PostDocProject/keras-gcn
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing kegra.egg-info/PKG-INFO
# writing dependency_links to kegra.egg-info/dependency_links.txt
# writing requirements to kegra.egg-info/requires.txt
# writing top-level names to kegra.egg-info/top_level.txt
# reading manifest file 'kegra.egg-info/SOURCES.txt'
# adding license file 'LICENCE'
# writing manifest file 'kegra.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/kegra
# copying build/lib/kegra/__init__.py -> build/bdist.linux-x86_64/egg/kegra
# copying build/lib/kegra/train.py -> build/bdist.linux-x86_64/egg/kegra
# creating build/bdist.linux-x86_64/egg/kegra/layers
# copying build/lib/kegra/layers/__init__.py -> build/bdist.linux-x86_64/egg/kegra/layers
# copying build/lib/kegra/layers/graph.py -> build/bdist.linux-x86_64/egg/kegra/layers
# copying build/lib/kegra/utils.py -> build/bdist.linux-x86_64/egg/kegra
# byte-compiling build/bdist.linux-x86_64/egg/kegra/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/kegra/train.py to train.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/kegra/layers/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/kegra/layers/graph.py to graph.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/kegra/utils.py to utils.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying kegra.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying kegra.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying kegra.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying kegra.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying kegra.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/kegra-0.0.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing kegra-0.0.1-py3.10.egg
# Copying kegra-0.0.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding kegra 0.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/kegra-0.0.1-py3.10.egg
# Processing dependencies for kegra==0.0.1
# Searching for keras==2.14.0
# Best match: keras 2.14.0
# Adding keras 2.14.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for kegra==0.0.1
# 2.14.0
# 2.14.0
# Python 3.10.12

# %%
# @title Default title text
# !pip install rdkit
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
import os
import numpy as np
import matplotlib.pyplot as plt
import json
import pickle
import collections
from collections import OrderedDict
from matplotlib.pyplot import cm
import numpy as np
from scipy.io import savemat, loadmat
import math

CHARPROTSET = { "A": 1, "C": 2, "B": 3, "E": 4, "D": 5, "G": 6,
                "F": 7, "I": 8, "H": 9, "K": 10, "M": 11, "L": 12,
                "O": 13, "N": 14, "Q": 15, "P": 16, "S": 17, "R": 18,
                "U": 19, "T": 20, "W": 21,
                "V": 22, "Y": 23, "X": 24,
                "Z": 25 }

CHARPROTLEN = 25

CHARCANSMISET = { "#": 1, "%": 2, ")": 3, "(": 4, "+": 5, "-": 6,
             ".": 7, "1": 8, "0": 9, "3": 10, "2": 11, "5": 12,
             "4": 13, "7": 14, "6": 15, "9": 16, "8": 17, "=": 18,
             "A": 19, "C": 20, "B": 21, "E": 22, "D": 23, "G": 24,
             "F": 25, "I": 26, "H": 27, "K": 28, "M": 29, "L": 30,
             "O": 31, "N": 32, "P": 33, "S": 34, "R": 35, "U": 36,
             "T": 37, "W": 38, "V": 39, "Y": 40, "[": 41, "Z": 42,
             "]": 43, "_": 44, "a": 45, "c": 46, "b": 47, "e": 48,
             "d": 49, "g": 50, "f": 51, "i": 52, "h": 53, "m": 54,
             "l": 55, "o": 56, "n": 57, "s": 58, "r": 59, "u": 60,
             "t": 61, "y": 62}

CHARCANSMILEN = 62

CHARISOSMISET = {"#": 29, "%": 30, ")": 31, "(": 1, "+": 32, "-": 33, "/": 34, ".": 2,
                "1": 35, "0": 3, "3": 36, "2": 4, "5": 37, "4": 5, "7": 38, "6": 6,
                "9": 39, "8": 7, "=": 40, "A": 41, "@": 8, "C": 42, "B": 9, "E": 43,
                "D": 10, "G": 44, "F": 11, "I": 45, "H": 12, "K": 46, "M": 47, "L": 13,
                "O": 48, "N": 14, "P": 15, "S": 49, "R": 16, "U": 50, "T": 17, "W": 51,
                "V": 18, "Y": 52, "[": 53, "Z": 19, "]": 54, "\\": 20, "a": 55, "c": 56,
                "b": 21, "e": 57, "d": 22, "g": 58, "f": 23, "i": 59, "h": 24, "m": 60,
                "l": 25, "o": 61, "n": 26, "s": 62, "r": 27, "u": 63, "t": 28, "y": 64}

CHARISOSMILEN = 64


## ######################## ##
#
#  Encoding Helpers
#
## ######################## ##

#  Y = -(np.log10(Y/(math.pow(math.e,9))))

def one_hot_smiles(line, MAX_SMI_LEN, smi_ch_ind):
    X = np.zeros((MAX_SMI_LEN, len(smi_ch_ind))) #+1

    for i, ch in enumerate(line[:MAX_SMI_LEN]):
        X[i, (smi_ch_ind[ch]-1)] = 1

    return X #.tolist()

def one_hot_sequence(line, MAX_SEQ_LEN, smi_ch_ind):
    X = np.zeros((MAX_SEQ_LEN, len(smi_ch_ind)))
    for i, ch in enumerate(line[:MAX_SEQ_LEN]):
        X[i, (smi_ch_ind[ch])-1] = 1

    return X #.tolist()


def label_smiles(line, MAX_SMI_LEN, smi_ch_ind):
    X = np.zeros(MAX_SMI_LEN)
    for i, ch in enumerate(line[:MAX_SMI_LEN]): #    x, smi_ch_ind, y
        X[i] = smi_ch_ind[ch]

    return X #.tolist()

def label_sequence(line, MAX_SEQ_LEN, smi_ch_ind):
    X = np.zeros(MAX_SEQ_LEN)

    for i, ch in enumerate(line[:MAX_SEQ_LEN]):
        X[i] = smi_ch_ind[ch]

    return X #.tolist()




# Set the following ones properly
f = open('/content/drive/My Drive/PDB/Y_PDB.txt', 'r')    # file which contain label of PDB data  (uploaded in git repository)
f1 = open('/content/drive/My Drive/PDB/name_PDB.txt', 'r')  # file which contain the name of samples in pdb dataset  (uploaded in git repository)
path_pdb = '/content/drive/My Drive/PDB/v2016'  # the path of dataset


XD = []  # matrix which stores drugs
XT = []  # matrix which stores proteins

y_value = []
y_unit = []
y_real = []
flag = []

# !pip install Bio

for i, l in enumerate(f):
    print(i)
    try:
        tmp = f.readline()
        value = tmp.split('>=')
        if len(value)<2:
            value = tmp.split('>')
            if len(value)<2:
               value = tmp.split('<=')
               if len(value)<2:
                  value = tmp.split('<')
                  if len(value)<2:
                     value = tmp.split('=')
                     if len(value)<2:
                        value = tmp.split('~')
                        if len(value)<2:
                           print(value)

        y_value.append(value[1][:-3])
        y_unit.append(value[0])
        if value[0] == 'IC50':
            #   flag.append(0)
            #if value[0] == 'Kd':
            #   flag.append(1)
            #if value[0] == 'Ki':
            #   flag.append(2)
            print(i)


            folder = f1.readline()
            folder = folder.split('.')[0]
            print(path_pdb+'/'+folder+'/'+folder+'_ligand.sdf')
            m = Chem.MolFromMolFile(path_pdb+'/'+folder+'/'+folder+'_ligand.sdf')
            print(path_pdb+'/'+folder+'/'+folder+'_ligand.sdf')
            #print(Chem.MolToSmiles(m))
            #print('here1')

            #print('here2')

            from Bio.PDB import PDBParser
              # this is the module described below
            d3to1 = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
            'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N',
            'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W',
            'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M', 'HOH': 'B'}
            # read
            sloppyparser = PDBParser(
                PERMISSIVE=True#, structure_builder=xpdb.SloppyStructureBuilder()
            )
            structure = sloppyparser.get_structure("MD_system", path_pdb + '/'+ folder+'/'+folder+'_protein.pdb')
            #print(structure.get_chains(structure.get_models()))
            struct = PDBParser(QUIET=True).get_structure('tmp', path_pdb + '/' + folder+'/'+folder+'_protein.pdb')
            #print(struct)
            count=0
            for model in structure:
                for chain in model:
                    if count==0:
                        seq = []
                        for residue in chain:
                            seq.append(d3to1[residue.resname])
                        #print(seq)
                        count=count+1

            XD.append(label_smiles(Chem.MolToSmiles(m), 100, CHARISOSMISET))

            XT.append(label_sequence(seq, 1000, CHARPROTSET))
            if value[1][-3:-1] == 'pM':
               y_real.append(float(value[1][:-3])* (0.001))
            if value[1][-3:-1] == 'uM':
               y_real.append(float(value[1][:-3])* (10^(3)))
            if value[1][-3:-1] == 'mM':
               y_real.append(float(value[1][:-3])* (10^6))
            if value[1][-3:-1] == 'fM':
               y_real.append(float(value[1][:-3])* (0.000001))
            if value[1][-3:-1] == 'nM':
               y_real.append(float(value[1][:-3]))

            if len(y_real) > 500:
              break;
    except:
        continue

print(type(y_value))
print(type(y_unit))
print(set(y_unit))
print(type(y_real))
print(np.sum(np.array(flag)==0))
print(np.sum(np.array(flag)==1))
print(np.sum(np.array(flag)==2))
print(len(y_real))
print(len(XD))
print(len(XT))

y_real = -(np.log10(np.array(y_real)/(math.pow(10,9)))) #-np.log(y_real/(10^9))

pdb={'XT': XT, 'XD': XD, 'Y': y_real}
savemat('pdb_xt.mat',pdb)
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.2

# %%
from scipy.io import savemat, loadmat
tmp = loadmat('pdb_xt.mat')
XD = tmp['XD']
XT = tmp['XT']
y_real = tmp['Y'].T

########################################
#  prepare  data                       #
########################################

# choose the appropriate flag
train_drugs = np.array(XD[0:350])
train_prots = np.array(XT[0:350])
train_Y = np.array(y_real[0:350])

threshold = np.median(train_Y)

val_drugs = np.array(XD[350:])
val_prots = np.array(XT[350:])
val_Y = np.array(y_real[350:])

#train_Y = np.reshape(train_Y,(train_Y.shape[1],))
#val_Y = np.reshape(val_Y,(val_Y.shape[1],))


num_train_samples = train_Y.shape[0]
num_val_samples = val_Y.shape[0]

###################################################


# Define parameters
DATASET = 'cora'
FILTER = 'localpool'  # 'chebyshev'
MAX_DEGREE = 2  # maximum polynomial degree
SYM_NORM = True  # symmetric (True) vs. left-only (False) normalization
NB_EPOCH = 0
PATIENCE = 10  # early stopping patience


def cindex_score(y_true, y_pred):

    g = tf.subtract(tf.expand_dims(y_pred, -1), y_pred)
    g = tf.cast(g == 0.0, tf.float32) * 0.5 + tf.cast(g > 0.0, tf.float32)

    f = tf.subtract(tf.expand_dims(y_true, -1), y_true) > 0.0
    f = tf.compat.v1.matrix_band_part(tf.cast(f, tf.float32), -1, 0)

    g = tf.reduce_sum(tf.multiply(g, f))
    f = tf.reduce_sum(f)

    return tf.where(tf.equal(g, 0), 0.0, g/f) #select

def dot_batch(inp):
    import tensorflow as tf
    return tf.math.sigmoid(tf.tensordot(inp[0][0:100],inp[1],axes=(1, 1)))

def dot_batch2(inp):
    import tensorflow as tf
    a=inp[0]
    b=inp[1]
    return tf.tensordot(a,b,axes=(0, 0))

# Compound Feature Extractor


Drug_input = Input(shape=(smiles_max_len,), dtype='int32',name='drug_input')
Protein_input = Input(shape=(protein_max_len,), dtype='int32',name='protein_input')
G = [Input(batch_shape=(None, None))]#, batch_shape=(None, None))]

encode_smiles = Embedding(input_dim=smiles_dict_len+1, output_dim = embedding_size, input_length=smiles_max_len,name='smiles_embedding')(Drug_input)
encode_smiles = Conv1D(filters=num_filters, kernel_size=smiles_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv1_smiles')(encode_smiles)
encode_smiles = Conv1D(filters=num_filters*2, kernel_size=smiles_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv2_smiles')(encode_smiles)
encode_smiles = Conv1D(filters=num_filters*3, kernel_size=smiles_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv3_smiles')(encode_smiles)



encode_protein = Embedding(input_dim=protein_dict_len+1, output_dim = embedding_size, input_length=protein_max_len, name='protein_embedding')(Protein_input)
encode_protein = Conv1D(filters=num_filters, kernel_size=protein_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv1_prot')(encode_protein)
encode_protein = Conv1D(filters=num_filters*2, kernel_size=protein_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv2_prot')(encode_protein)
encode_protein = Conv1D(filters=num_filters*3, kernel_size=protein_filter_lengths,  activation='relu', padding='valid',  strides=1, name='conv3_prot')(encode_protein)

encode_protein = GlobalMaxPooling1D()(encode_protein)
encode_smiles = GlobalMaxPooling1D()(encode_smiles)



protein_desc_len=96


X_in =Concatenate()([encode_protein,encode_smiles])  # this correspond with node descriptor
X_in= LayerNormalization()(X_in)

model_Feat = Model(inputs=[Drug_input, Protein_input], outputs=[X_in])

input_adj = Input(shape=(num_filters*6,))
FC1 = Dense(1024, activation='relu', name='dense1')(input_adj)
FC2 = Dropout(0.1)(FC1)
FC2 = Dense(1024, activation='relu', name='dense2')(FC2)
FC2 = Dropout(0.1)(FC2)
FC2 = Dense(512, activation='relu', name='dense3')(FC2)
# And add a logistic regression on top
G1 = Dense(1, kernel_initializer='normal',  name='dense4')(FC2) # if you want train model for active/inactive set activation='sigmoid'

model_Adj = Model(inputs=input_adj, outputs=[G1])


H = Dropout(0.5)(X_in)
H = GraphConvolution(512, support, activation='relu', kernel_regularizer=l2(5e-4))([X_in]+G) #, kernel_regularizer=l2(5e-4)
#H = Dropout(0.5)(H)
#H = GraphConvolution(192, support, activation='relu', kernel_regularizer=l2(5e-4))([H]+G)
H = GraphConvolution(256, support, activation='relu', kernel_regularizer=l2(5e-4))([H]+G)

Y = GraphConvolution(192, support, activation='relu', kernel_regularizer=l2(5e-4))([H]+G) #activation='sigmoid',, name='main_out'

Y = Add()([Y,X_in])
Y = Dense(1024, activation='relu')(Y)
Y = Dropout(0.1)(Y)
Y = Dense(1024, activation='relu')(Y)
Y = Dropout(0.1)(Y)
Y = Dense(512, activation='relu')(Y)
# And add a logistic regression on top
Y = Dense(1)(Y)

model_Semi = Model(inputs=[Drug_input, Protein_input,G], outputs=Y)

# Compile model

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR') # precision-recall curve
]

def weighted_bce(y_true, y_pred):
  y_true = keras.backend.cast(y_true,"float32")
  weights = (y_true * 18.) + 1.
  bce = keras.backend.binary_crossentropy(y_true, y_pred)
  weighted_bce = keras.backend.mean(bce * weights)
  return weighted_bce
def bce(y_true, y_pred):
  y_true = keras.backend.cast(y_true,"float32")

  bce = keras.backend.binary_crossentropy(y_true[0,:], y_pred[0,:])
  weighted_bce = keras.backend.mean(bce)
  return weighted_bce

out_ = model_Adj(model_Feat([Drug_input,Protein_input]))
model2 = Model(inputs=[Drug_input,Protein_input], outputs=out_)
model2.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate_feat_model),metrics=['mse',cindex_score]) #weighted_bce


import keras.backend as K
def mean_squared_error_w(y_true, y_pred):
    mses = K.mean(K.square(y_pred - y_true), axis = -1)
    std_of_pred = K.std(y_pred)
    std_of_true = K.std(y_true)
    mses_std =K.square(std_of_pred - std_of_true)
    #const = K.mean(mses, axis = -1) + (std_of_mses * 0.5)
    #mask = K.cast(K.less(K.mean(K.square(y_pred - y_true), axis=-1), const), dtype = "float32")
    return mses_std+mses
def mean_squared_error_w1(y_true, y_pred):
    mses = K.mean(K.square(y_pred - y_true), axis = -1)
    std_of_mses = K.std(mses)
    const = K.mean(mses, axis = -1) + (std_of_mses * 0.5)
    mask = K.cast(K.less(K.mean(K.square(y_pred - y_true), axis=-1), const), dtype = "float32")
    return mask * K.mean(K.square(y_pred - y_true), axis=-1)

METRICS = [
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR') # precision-recall curve
]
model_Semi.compile(loss=['mse'], optimizer=Adam(learning_rate=learning_rate_GCN),metrics=['mse',cindex_score])
# Helper variables for main training loop
wait = 0
preds = None
best_val_loss = 99999



###########################################
#  Design Generator                       #
###########################################
from scipy.sparse import csr_matrix
def generate_data(batch_size,flag):
  i_c=0
  while True:
        input1 = []
        input2 = []

        output1 = []
        batch_counter=0

        if (i_c+batch_size)>num_train_samples:
          i_c= i_c - ((i_c+batch_size) - num_train_samples )
        elif (i_c+batch_size)==num_train_samples:
          i_c = 0

        G_all = model_Feat.predict([np.array(train_drugs),np.array(train_prots)],batch_size=batch_size)

        in_drug=train_drugs[i_c:i_c+batch_size]
        in_prots=train_prots[i_c:i_c+batch_size]
        #G = model2.predict([np.array(input1[0:batch_size]),np.array(input2[0:batch_size])],batch_size=batch_size)


        idx = np.concatenate((range(0,i_c),range(i_c+1+batch_size,train_drugs.shape[0])))
        idx=idx.astype(int)
        #################################################################
        ## Retrieval step
        #################################################################
        G_all = np.array(G_all)
        paired_dist = scipy.spatial.distance.cdist(G_all[i_c:(i_c+batch_size), :], G_all[idx, :])
        idx_out = np.argsort(paired_dist, axis = 1)
        Y_sorted  = np.reshape([train_Y[idx[index2]]>threshold  for index in idx_out for index2 in index], (batch_size, len(idx)))
        local_pattern = Y_sorted
        out = scipy.signal.convolve2d(local_pattern, [[1, -1]], mode='same')
        idx_ = []
        for ii in range(out.shape[0]):
          for jj in range(out.shape[1]):
            if out[ii, jj] != 0:
              idx_.append(idx_out[ii, jj])

        idx_ = np.unique(np.array(idx_))
        if len(idx_) >= 10*batch_size:
           pindex = np.random.choice(idx_.shape[0], 10*batch_size, replace=False)
           pindex = idx_[pindex]
        else:
           pindex = np.random.choice(idx_.shape[0], (10*batch_size), replace=True)
           pindex = idx_[pindex]
        ###############################################################################
        #pindex = np.random.choice(idx.shape[0], 10*batch_size, replace=False)
        input1 = np.concatenate((in_drug,train_drugs[idx[pindex]]), axis=0)
        input2 = np.concatenate((in_prots,train_prots[idx[pindex]]), axis=0)

        output1 = np.concatenate((train_Y[i_c:i_c+batch_size],train_Y[idx[pindex]]), axis=0)
        output1 = np.reshape(output1,(10*batch_size+batch_size,1))
        print(np.sum(train_Y[idx[pindex]]>threshold))
        G = model2.predict([np.array(input1[0:batch_size]),np.array(input2[0:batch_size])],batch_size=batch_size)

        output1_ = (output1>threshold)
        output1_ = output1_.astype(int)
        tmpp=np.matmul(output1_,np.transpose(output1_))+np.matmul(1-output1_,np.transpose(1-output1_))


        G1=np.array(G)
        G1 = (G1>threshold)
        G1 = G1.astype(int)

        G1 = np.matmul(G1,np.transpose(output1_))+np.matmul(1-G1,np.transpose(1-output1_))

        Adj = np.vstack((np.reshape(G1[0:batch_size,batch_size:],(batch_size,10*batch_size)),tmpp[batch_size:,batch_size:]))
        Adj = np.hstack((np.reshape(G1,(batch_size+10*batch_size,batch_size)),Adj)) # [0:100,:]

        Adj = Adj+np.eye(Adj.shape[0])
        d = np.diag(np.power(np.array(Adj.sum(1)), -0.5).flatten(), 0)
        Adj = Adj.dot(d).transpose().dot(d)


        """print(np.array(input1).shape)
        print(np.array(input2).shape)
        print(Adj.shape)
        print(np.array(output1).shape)
        print(batch_size)"""

        i_c=i_c+batch_size
        model_Semi.fit([np.array(input1),np.array(input2), Adj],np.array(output1),sample_weight=np.concatenate((np.zeros((batch_size,)),np.ones((10*batch_size,)))),
                 batch_size=10*batch_size+batch_size, epochs=10, shuffle=False, )

        if flag==1:
           yield [np.array(input1),np.array(input2), Adj], np.array(output1), np.concatenate((np.zeros((batch_size,)),np.ones((10*batch_size,))))
        else:
           yield [np.array(input1),np.array(input2), Adj], output1_[0:batch_size]


def generate_data_val(batch_size_test, batch_size,flag):
  i_c=0
  while True:
        input1 = []
        input2 = []

        output1 = []
        batch_counter=0

        if i_c>=num_val_samples:
          i_c=0


        in_drug=val_drugs[i_c:i_c+batch_size_test]
        in_prots=val_prots[i_c:i_c+batch_size_test]

        G_all = model_Feat.predict([np.array(train_drugs),np.array(train_prots)],batch_size=batch_size)

        idx = np.concatenate((range(0,i_c),range(i_c+1+batch_size_test,train_drugs.shape[0])))
        idx=idx.astype(int)
        #################################################################
        ## Retrieval step
        #################################################################
        G_all = np.array(G_all)
        paired_dist = scipy.spatial.distance.cdist(G_all[i_c:(i_c+batch_size_test), :], G_all[idx, :])
        idx_out = np.argsort(paired_dist, axis =1)
        Y_sorted  = np.reshape([train_Y[idx[index2]]>threshold  for index in idx_out for index2 in index], (batch_size, len(idx)))
        local_pattern = Y_sorted
        out = scipy.signal.convolve2d(local_pattern, [[1, -1]], mode='same')
        idx_ = []
        for ii in range(out.shape[0]):
          for jj in range(out.shape[1]):
            if out[ii, jj] != 0:
              idx_.append(idx_out[ii, jj])

        idx_ = np.unique(np.array(idx_))
        if len(idx_) >= 10*batch_size:
           pindex = np.random.choice(idx_.shape[0], 10*batch_size, replace=False)
           pindex = idx_[pindex]
        else:
           pindex = np.random.choice(idx_.shape[0], (10*batch_size), replace=True)
           pindex = idx_[pindex]
        #########################################################################
        #pindex = np.random.choice(idx.shape[0], 10*batch_size, replace=False)
        #print(pindex)

        input1 = np.concatenate((in_drug,train_drugs[idx[pindex]]), axis=0)
        input2 = np.concatenate((in_prots,train_prots[idx[pindex]]), axis=0)


        output1 = np.concatenate((val_Y[i_c:i_c+batch_size_test],train_Y[idx[pindex]]), axis=0)
        output1 = np.reshape(output1,(batch_size+10*batch_size,1))

        G = model2.predict([np.array(input1[0:batch_size]),np.array(input2[0:batch_size])],batch_size=batch_size)

        output1_ = (output1>threshold)
        output1_ = output1_.astype(int)
        tmpp=np.matmul(output1_,np.transpose(output1_))+np.matmul(1-output1_,np.transpose(1-output1_))


        G1=np.array(G)
        G1 = (G1>threshold)
        G1 = G1.astype(int)

        G1 = np.matmul(G1,np.transpose(output1_))+np.matmul(1-G1,np.transpose(1-output1_))

        Adj = np.vstack((np.reshape(G1[0:batch_size,batch_size:],(batch_size,10*batch_size)),tmpp[batch_size:,batch_size:]))
        Adj = np.hstack((np.reshape(G1,(10*batch_size+batch_size,batch_size)),Adj)) # [0:100,:]

        Adj = Adj+np.eye(Adj.shape[0])
        d = np.diag(np.power(np.array(Adj.sum(1)), -0.5).flatten(), 0)
        Adj = Adj.dot(d).transpose().dot(d)

        print(np.array(input1).shape)
        print(np.array(input2).shape)
        print(Adj.shape)
        print(np.array(output1).shape)
        print(batch_size)

        i_c=i_c+batch_size_test
        """for kk in range(0,10):
            model_Semi.fit([np.array(input1),np.array(input2), Adj],np.array(output1),sample_weight=np.concatenate((np.zeros((batch_size1,)),np.ones((10*batch_size1,)))),
                 batch_size=1100, epochs=1, shuffle=False)
        """
        if flag==1:
           yield [np.array(input1),np.array(input2), Adj], np.array(output1), np.concatenate((np.zeros((batch_size,)),np.ones((10*batch_size,))))
        else:
           yield [np.array(input1),np.array(input2), Adj], output1_[0:batch_size]

num_train_samples = len(train_drugs)

for epoch in range(0, NB_EPOCH+1):
    #batch_size1=100
    model_Adj.trainable=True
    model_Feat.trainable=True

    #model2.fit(([np.array(train_drugs),np.array(train_prots) ]), np.array(train_Y), batch_size=512, epochs=10,
    #                         validation_data=( ([np.array(val_drugs), np.array(val_prots) ]), np.array(val_Y)),  shuffle=False )
    import scipy
    #model_Adj.trainable=False
    model_Feat.trainable=False
    batch_size = 256
    history = model_Semi.fit_generator(generator=generate_data(batch_size,1),
              steps_per_epoch = num_train_samples/batch_size, epochs=20, shuffle=False, verbose=1)#,validation_data=generate_data_val(batch_size1), validation_steps=50)
# Out:
# 2/2 [==============================] - 1s 27ms/step
# 1521
# 1/1 [==============================] - 1s 1s/step
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.4032 - mse: 1.1815 - cindex_score: 0.3805
# Epoch 6/10
# 1/1 [==============================] - 1s 825ms/step - loss: 1.3900 - mse: 1.1685 - cindex_score: 0.3844
# Epoch 7/10
# 1/1 [==============================] - 1s 838ms/step - loss: 1.3736 - mse: 1.1516 - cindex_score: 0.3899
# Epoch 8/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.3572 - mse: 1.1438 - cindex_score: 0.3855
# Epoch 9/10
# 1/1 [==============================] - 1s 924ms/step - loss: 1.3602 - mse: 1.1530 - cindex_score: 0.3757
# Epoch 10/10
# 1/1 [==============================] - 1s 832ms/step - loss: 1.3419 - mse: 1.1342 - cindex_score: 0.3920
# 2/2 [==============================] - 0s 130ms/step
# 233
# 1/1 [==============================] - 0s 481ms/step
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.2709 - mse: 1.0754 - cindex_score: 0.4028
# Epoch 2/10
# 1/1 [==============================] - 1s 926ms/step - loss: 1.2665 - mse: 1.0750 - cindex_score: 0.3951
# Epoch 3/10
# 1/1 [==============================] - 1s 820ms/step - loss: 1.2562 - mse: 1.0736 - cindex_score: 0.3919
# Epoch 4/10
# 1/1 [==============================] - 1s 882ms/step - loss: 1.2330 - mse: 1.0497 - cindex_score: 0.4044
# Epoch 5/10
# 1/1 [==============================] - 1s 819ms/step - loss: 1.2351 - mse: 1.0615 - cindex_score: 0.3945
# Epoch 6/10
# 1/1 [==============================] - 1s 836ms/step - loss: 1.2135 - mse: 1.0416 - cindex_score: 0.3956
# Epoch 7/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.2303 - mse: 1.0604 - cindex_score: 0.3948
# Epoch 8/10
# 1/1 [==============================] - 1s 819ms/step - loss: 1.2147 - mse: 1.0458 - cindex_score: 0.3995
# Epoch 9/10
# 1/1 [==============================] - 1s 847ms/step - loss: 1.2079 - mse: 1.0379 - cindex_score: 0.4052
# Epoch 10/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.1866 - mse: 1.0239 - cindex_score: 0.4154
# 1/1 [==============================] - 33s 46s/step - loss: 1.2222 - mse: 1.0435 - cindex_score: 0.4094
# 2/2 [==============================] - 1s 18ms/step
# Epoch 7/20
# 232
# 1/1 [==============================] - 0s 175ms/step
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.1900 - mse: 1.0428 - cindex_score: 0.3957
# Epoch 2/10
# 1/1 [==============================] - 1s 833ms/step - loss: 1.1824 - mse: 1.0353 - cindex_score: 0.4021
# Epoch 3/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.1791 - mse: 1.0449 - cindex_score: 0.4000
# Epoch 4/10
# 1/1 [==============================] - 1s 924ms/step - loss: 1.1753 - mse: 1.0373 - cindex_score: 0.4004
# Epoch 5/10
# 1/1 [==============================] - 1s 829ms/step - loss: 1.1804 - mse: 1.0500 - cindex_score: 0.4067
# Epoch 6/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.1782 - mse: 1.0457 - cindex_score: 0.4048
# Epoch 7/10
# 1/1 [==============================] - 1s 913ms/step - loss: 1.1776 - mse: 1.0498 - cindex_score: 0.3935
# Epoch 8/10
# 1/1 [==============================] - 1s 997ms/step - loss: 1.1713 - mse: 1.0361 - cindex_score: 0.4040
# Epoch 9/10
# 1/1 [==============================] - 1s 991ms/step - loss: 1.1608 - mse: 1.0363 - cindex_score: 0.4084
# Epoch 10/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.1665 - mse: 1.0384 - cindex_score: 0.3985
# 2/2 [==============================] - 1s 17ms/step
# 271
# 1/1 [==============================] - 0s 20ms/step
# Epoch 1/10
# 1/1 [==============================] - 1s
ms/step
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6208 - mse: 0.4498 - cindex_score: 0.6928
# Epoch 2/10
# 1/1 [==============================] - 1s 824ms/step - loss: 0.6229 - mse: 0.4552 - cindex_score: 0.6944
# Epoch 3/10
# 1/1 [==============================] - 1s 963ms/step - loss: 0.6248 - mse: 0.4538 - cindex_score: 0.6918
# Epoch 4/10
# 1/1 [==============================] - 1s 997ms/step - loss: 0.6178 - mse: 0.4490 - cindex_score: 0.6925
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6242 - mse: 0.4540 - cindex_score: 0.6913
# Epoch 6/10
# 1/1 [==============================] - 1s 975ms/step - loss: 0.6166 - mse: 0.4487 - cindex_score: 0.6977
# Epoch 7/10
# 1/1 [==============================] - 1s 996ms/step - loss: 0.6179 - mse: 0.4440 - cindex_score: 0.6947
# Epoch 8/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.6223 - mse: 0.4530 - cindex_score: 0.6864
# Epoch 9/10
# 1/1 [==============================] - 1s 995ms/step - loss: 0.6199 - mse: 0.4398 - cindex_score: 0.6963
# Epoch 10/10
# 1/1 [==============================] - 1s 834ms/step - loss: 0.6170 - mse: 0.4477 - cindex_score: 0.6935
# 1/1 [==============================] - 30s 40s/step - loss: 0.6188 - mse: 0.4507 - cindex_score: 0.6929
# 2/2 [==============================] - 0s 308ms/step
# Epoch 19/20
# 245
# 1/1 [==============================] - 1s 738ms/step
# Epoch 1/10
# 1/1 [==============================] - 1s 893ms/step - loss: 0.6109 - mse: 0.4375 - cindex_score: 0.6916
# Epoch 2/10
# ...
# Epoch 20/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4893 - mse: 0.2573 - cindex_score: 0.8544
# 1/1 [==============================] - 0s 18ms/step
# 350/350 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 38ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5353 - mse: 0.2250 - cindex_score: 0.8242
# Epoch 2/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5184 - mse: 0.2188 - cindex_score: 0.8254
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5205 - mse: 0.2107 - cindex_score: 0.8268
# Epoch 4/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5015 - mse: 0.1940 - cindex_score: 0.8385
# Epoch 5/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5089 - mse: 0.1981 - cindex_score: 0.8311
# Epoch 6/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5328 - mse: 0.2165 - cindex_score: 0.8180
# Epoch 7/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5116 - mse: 0.2062 - cindex_score: 0.8216
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4974 - mse: 0.1811 - cindex_score: 0.8317
# Epoch 9/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5000 - mse: 0.1907 - cindex_score: 0.8387
# Epoch 10/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4824 - mse: 0.1753 - cindex_score: 0.8462
# Epoch 11/20
# 1/1 [==============================] - 0s 297ms/step - loss: 0.5093 - mse: 0.1977 - cindex_score: 0.8230
# Epoch 12/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5076 - mse: 0.1956 - cindex_score: 0.8244
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4983 - mse: 0.1831 - cindex_score: 0.8335
# Epoch 14/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4993 - mse: 0.1898 - cindex_score: 0.8409
# Epoch 15/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4858 - mse: 0.1815 - cindex_score: 0.8391
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4892 - mse: 0.1776 - cindex_score: 0.8449
# Epoch 17/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4928 - mse: 0.1825 - cindex_score: 0.8317
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4973 - mse: 0.1989 - cindex_score: 0.8399
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4968 - mse: 0.1855 - cindex_score: 0.8439
# Epoch 20/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4675 - mse: 0.1674 - cindex_score: 0.8564
# 1/1 [==============================] - 0s 28ms/step
# 350/350 [==============================] - 2s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5246 - mse: 0.2142 - cindex_score: 0.8682
# Epoch 2/20
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5358 - mse: 0.2184 - cindex_score: 0.8646
# Epoch 3/20
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5038 - mse: 0.1896 - cindex_score: 0.8713
# Epoch 4/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5092 - mse: 0.1973 - cindex_score: 0.8700
# Epoch 5/20
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5387 - mse: 0.2261 - cindex_score: 0.8509
# Epoch 6/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5359 - mse: 0.2168 - cindex_score: 0.8731
# Epoch 7/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5076 - mse: 0.1965 - cindex_score: 0.8725
# Epoch 8/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5171 - mse: 0.2025 - cindex_score: 0.8727
# Epoch 9/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5334 - mse: 0.2204 - cindex_score: 0.8600
# Epoch 10/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5219 - mse: 0.2141 - cindex_score: 0.8630
# Epoch 11/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5088 - mse: 0.1980 - cindex_score: 0.8650
# Epoch 12/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5039 - mse: 0.1906 - cindex_score: 0.8684
# Epoch 13/20
# 1/1 [==============================] - 0s 305ms/step - loss: 0.5400 - mse: 0.2278 - cindex_score: 0.8614
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5162 - mse: 0.2096 - cindex_score: 0.8560
# Epoch 15/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5030 - mse: 0.1921 - cindex_score: 0.8765
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4972 - mse: 0.1853 - cindex_score: 0.8668
# Epoch 17/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5237 - mse: 0.2173 - cindex_score: 0.8521
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4931 - mse: 0.1814 - cindex_score: 0.8809
# Epoch 19/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5310 - mse: 0.2222 - cindex_score: 0.8634
# Epoch 20/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4763 - mse: 0.1653 - cindex_score: 0.8787
# 1/1 [==============================] - 0s 185ms/step
# 350/350 [==============================] - 3s 9ms/step
# 1/1 [==============================] - 0s 27ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6525 - mse: 0.4040 - cindex_score: 0.7975
# Epoch 2/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6574 - mse: 0.3859 - cindex_score: 0.8008
# Epoch 3/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6767 - mse: 0.4208 - cindex_score: 0.7816
# Epoch 4/20
# 1/1 [==============================] - 1s 822ms/step - loss: 0.6133 - mse: 0.3318 - cindex_score: 0.8280
# Epoch 5/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6337 - mse: 0.3774 - cindex_score: 0.8080
# Epoch 6/20
# 1/1 [==============================] - 1s 835ms/step - loss: 0.6036 - mse: 0.3316 - cindex_score: 0.8139
# Epoch 7/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6033 - mse: 0.3475 - cindex_score: 0.8159
# Epoch 8/20
# 1/1 [==============================] - 0s 240ms/step - loss: 0.6015 - mse: 0.3792 - cindex_score: 0.8217
# Epoch 9/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6006 - mse: 0.3357 - cindex_score: 0.8120
# Epoch 10/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5671 - mse: 0.3053 - cindex_score: 0.8380
# Epoch 11/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5823 - mse: 0.3228 - cindex_score: 0.8227
# Epoch 12/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5792 - mse: 0.3153 - cindex_score: 0.8292
# Epoch 13/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5305 - mse: 0.2660 - cindex_score: 0.8489
# Epoch 14/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5442 - mse: 0.2866 - cindex_score: 0.8427
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5440 - mse: 0.2915 - cindex_score: 0.8370
# Epoch 16/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5492 - mse: 0.2962 - cindex_score: 0.8461
# Epoch 17/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5480 - mse: 0.2894 - cindex_score: 0.8435
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5184 - mse: 0.2608 - cindex_score: 0.8614
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5309 - mse: 0.3021 - cindex_score: 0.8453
# Epoch 20/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5119 - mse: 0.2459 - cindex_score: 0.8616
# 1/1 [==============================] - 0s 28ms/step
# 350/350 [==============================] - 2s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5878 - mse: 0.2772 - cindex_score: 0.8490
# Epoch 2/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5308 - mse: 0.2149 - cindex_score: 0.8742
# Epoch 3/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5421 - mse: 0.2253 - cindex_score: 0.8446
# Epoch 4/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5216 - mse: 0.2046 - cindex_score: 0.8482
# Epoch 5/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5280 - mse: 0.2068 - cindex_score: 0.8621
# Epoch 6/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5237 - mse: 0.2057 - cindex_score: 0.8643
# Epoch 7/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5406 - mse: 0.2212 - cindex_score: 0.8545
# Epoch 8/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5327 - mse: 0.2172 - cindex_score: 0.8601
# Epoch 9/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4928 - mse: 0.1744 - cindex_score: 0.8772
# Epoch 10/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4798 - mse: 0.1672 - cindex_score: 0.8669
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4902 - mse: 0.1754 - cindex_score: 0.8744
# Epoch 12/20
# 1/1 [==============================] - 1s 821ms/step - loss: 0.5483 - mse: 0.2385 - cindex_score: 0.8498
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5414 - mse: 0.2325 - cindex_score: 0.8575
# Epoch 14/20
# 1/1 [==============================] - 0s 281ms/step - loss: 0.5111 - mse: 0.1968 - cindex_score: 0.8639
# Epoch 15/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5029 - mse: 0.1850 - cindex_score: 0.8663
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4733 - mse: 0.1567 - cindex_score: 0.8748
# Epoch 17/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4959 - mse: 0.1793 - cindex_score: 0.8599
# Epoch 18/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4888 - mse: 0.1686 - cindex_score: 0.8774
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5073 - mse: 0.1905 - cindex_score: 0.8617
# Epoch 20/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4940 - mse: 0.1794 - cindex_score: 0.8669
# 1/1 [==============================] - 0s 140ms/step
# 350/350 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5668 - mse: 0.3432 - cindex_score: 0.8453
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6067 - mse: 0.3612 - cindex_score: 0.8364
# Epoch 3/20
# 1/1 [==============================] - 1s 874ms/step - loss: 0.5592 - mse: 0.3220 - cindex_score: 0.8447
# Epoch 4/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5750 - mse: 0.3113 - cindex_score: 0.8286
# Epoch 5/20
# 1/1 [==============================] - 0s 316ms/step - loss: 0.5824 - mse: 0.3297 - cindex_score: 0.8403
# Epoch 6/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5226 - mse: 0.2909 - cindex_score: 0.8501
# Epoch 7/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5595 - mse: 0.3040 - cindex_score: 0.8372
# Epoch 8/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5850 - mse: 0.3429 - cindex_score: 0.8322
# Epoch 9/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5576 - mse: 0.3099 - cindex_score: 0.8308
# Epoch 10/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5683 - mse: 0.3213 - cindex_score: 0.8427
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5290 - mse: 0.3006 - cindex_score: 0.8409
# Epoch 12/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5336 - mse: 0.2634 - cindex_score: 0.8441
# Epoch 13/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5208 - mse: 0.2695 - cindex_score: 0.8497
# Epoch 14/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5433 - mse: 0.2974 - cindex_score: 0.8463
# Epoch 15/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5543 - mse: 0.3030 - cindex_score: 0.8405
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5355 - mse: 0.2980 - cindex_score: 0.8455
# Epoch 17/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5092 - mse: 0.2639 - cindex_score: 0.8534
# Epoch 18/20
# 1/1 [==============================] - 0s 392ms/step - loss: 0.5062 - mse: 0.2508 - cindex_score: 0.8552
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4815 - mse: 0.2268 - cindex_score: 0.8669
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5335 - mse: 0.2716 - cindex_score: 0.8427
# 1/1 [==============================] - 0s 67ms/step
# 350/350 [==============================] - 3s 9ms/step
# 1/1 [==============================] - 0s 49ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 253ms/step - loss: 0.5435 - mse: 0.2250 - cindex_score: 0.8592
# Epoch 2/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5544 - mse: 0.2341 - cindex_score: 0.8637
# Epoch 3/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5184 - mse: 0.1990 - cindex_score: 0.8629
# Epoch 4/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5075 - mse: 0.1917 - cindex_score: 0.8699
# Epoch 5/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5465 - mse: 0.2274 - cindex_score: 0.8532
# Epoch 6/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5369 - mse: 0.2199 - cindex_score: 0.8558
# Epoch 7/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4979 - mse: 0.1817 - cindex_score: 0.8675
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5760 - mse: 0.2642 - cindex_score: 0.8379
# Epoch 9/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5122 - mse: 0.1973 - cindex_score: 0.8707
# Epoch 10/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5428 - mse: 0.2286 - cindex_score: 0.8556
# Epoch 11/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4997 - mse: 0.1841 - cindex_score: 0.8647
# Epoch 12/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5255 - mse: 0.2101 - cindex_score: 0.8506
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4862 - mse: 0.1679 - cindex_score: 0.8800
# Epoch 14/20
# 1/1 [==============================] - 0s 277ms/step - loss: 0.4945 - mse: 0.1786 - cindex_score: 0.8790
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5157 - mse: 0.1980 - cindex_score: 0.8605
# Epoch 16/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5193 - mse: 0.2021 - cindex_score: 0.8687
# Epoch 17/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5139 - mse: 0.1960 - cindex_score: 0.8568
# Epoch 18/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5000 - mse: 0.1827 - cindex_score: 0.8695
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5195 - mse: 0.2053 - cindex_score: 0.8568
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4911 - mse: 0.1737 - cindex_score: 0.8828
# 1/1 [==============================] - 0s 28ms/step
# 350/350 [==============================] - 1s 4ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8bf6f4c15d16> in <cell line: 395>()
#     405     in_prots=val_prots[i_c:i_c+batch_size_test]
#     406
# --> 407     G_all = model_Feat.predict([np.array(train_drugs), np.array(train_prots)], batch_size=batch_size)
#     408
#     409     idx = np.concatenate((range(0, i_c), range(i_c + 1 + batch_size_test, train_drugs.shape[0])))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
# Test Phase
i_c=0
batch_size_test = 1
batch_size = 1
preds= []
num_neighbours_test = 100
while True:
    input1 = []
    input2 = []
    output1 = []
    batch_counter=0

    if i_c>=num_val_samples:
        break

    in_drug=val_drugs[i_c:i_c+batch_size_test]
    in_prots=val_prots[i_c:i_c+batch_size_test]

    G_all = model_Feat.predict([np.array(train_drugs), np.array(train_prots)], batch_size=batch_size)

    idx = np.concatenate((range(0, i_c), range(i_c + 1 + batch_size_test, train_drugs.shape[0])))
    idx = idx.astype(int)


    #################################################################
    ## Retrieval step
    #################################################################
    G_all = np.array(G_all)
    paired_dist = scipy.spatial.distance.cdist(G_all[i_c:(i_c + batch_size_test), :], G_all[idx, :])
    idx_out = np.argsort(paired_dist, axis=1)
    Y_sorted = np.reshape([train_Y[idx[index2]] > threshold for index in idx_out for index2 in index],
                          (batch_size, len(idx)))
    local_pattern = Y_sorted
    out = scipy.signal.convolve2d(local_pattern, [[1, -1]], mode='same')
    idx_ = []
    for ii in range(out.shape[0]):
        for jj in range(out.shape[1]):
            if out[ii, jj] != 0:
                idx_.append(idx_out[ii, jj])

    idx_ = np.unique(np.array(idx_))
    if len(idx_) >= 10 * batch_size:
        pindex = np.random.choice(idx_.shape[0], 10 * batch_size, replace=False)
        pindex = idx_[pindex]
    else:
        pindex = np.random.choice(idx_.shape[0], (10 * batch_size), replace=True)
        pindex = idx_[pindex]
    #########################################################################

    pindex = np.random.choice(idx.shape[0], num_neighbours_test, replace=False)
    #print(pindex)

    input1 = np.concatenate((in_drug,train_drugs[idx[pindex]]), axis=0)
    input2 = np.concatenate((in_prots,train_prots[idx[pindex]]), axis=0)


    output1 = np.concatenate((val_Y[i_c:i_c+batch_size_test],train_Y[idx[pindex]]), axis=0)
    output1 = np.reshape(output1,(num_neighbours_test+batch_size_test,1))

    G = model2.predict([np.array(input1[0:batch_size_test]),np.array(input2[0:batch_size_test])],batch_size=batch_size_test)

    output1_ = (output1>threshold)
    output1_ = output1_.astype(int)
    tmpp=np.matmul(output1_,np.transpose(output1_))+np.matmul(1-output1_,np.transpose(1-output1_))


    G1=np.array(G)
    G1 = (G1>threshold)
    G1 = G1.astype(int)

    G1 = np.matmul(G1,np.transpose(output1_))+np.matmul(1-G1,np.transpose(1-output1_))

    Adj = np.vstack((np.reshape(G1[0:batch_size_test,batch_size_test:],(batch_size_test,num_neighbours_test)),tmpp[batch_size_test:,batch_size_test:]))
    Adj = np.hstack((np.reshape(G1,(num_neighbours_test+batch_size_test,batch_size_test)),Adj)) # [0:100,:]

    Adj = Adj+np.eye(Adj.shape[0])
    d = np.diag(np.power(np.array(Adj.sum(1)), -0.5).flatten(), 0)
    Adj = Adj.dot(d).transpose().dot(d)



    i_c=i_c+batch_size_test
    model_Semi.fit([np.array(input1),np.array(input2), Adj],np.array(output1),sample_weight=np.concatenate((np.zeros((batch_size_test,)),np.ones((num_neighbours_test,)))),
            batch_size=num_neighbours_test+batch_size_test, epochs=num_epoch_GCN_inference, shuffle=False)

    preds.append(model_Semi.predict([np.array(input1),np.array(input2), Adj], batch_size=num_neighbours_test+batch_size_test)[0])
print(preds)

preds_m=preds
m=keras.metrics.MeanSquaredError()
m.update_state(preds_m,val_Y)
print("MSE= {:.4f}".format(m.result().numpy()))
print(cindex_score(val_Y,preds_m))
# Out:
# 350/350 [==============================] - 6s 18ms/step
# 1/1 [==============================] - 0s 491ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4639 - mse: 0.2590 - cindex_score: 0.8622
# Epoch 2/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4309 - mse: 0.2329 - cindex_score: 0.8797
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4486 - mse: 0.2462 - cindex_score: 0.8714
# Epoch 4/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4335 - mse: 0.2388 - cindex_score: 0.8775
# Epoch 5/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4118 - mse: 0.2144 - cindex_score: 0.8729
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4101 - mse: 0.2094 - cindex_score: 0.8888
# Epoch 7/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4387 - mse: 0.2474 - cindex_score: 0.8656
# Epoch 8/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4295 - mse: 0.2331 - cindex_score: 0.8765
# Epoch 9/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4046 - mse: 0.2222 - cindex_score: 0.8795
# Epoch 10/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4194 - mse: 0.2286 - cindex_score: 0.8823
# Epoch 11/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4291 - mse: 0.2354 - cindex_score: 0.8747
# Epoch 12/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4375 - mse: 0.2488 - cindex_score: 0.8755
# Epoch 13/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4081 - mse: 0.2150 - cindex_score: 0.8815
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4225 - mse: 0.2225 - cindex_score: 0.8813
# Epoch 15/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4004 - mse: 0.2054 - cindex_score: 0.8880
# Epoch 16/20
# 1/1 [==============================] - 0s 207ms/step - loss: 0.4072 - mse: 0.2017 - cindex_score: 0.8825
# Epoch 17/20
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4185 - mse: 0.2221 - cindex_score: 0.8777
# Epoch 18/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4044 - mse: 0.2037 - cindex_score: 0.8882
# Epoch 19/20
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4214 - mse: 0.2272 - cindex_score: 0.8837
# Epoch 20/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3832 - mse: 0.1791 - cindex_score: 0.8956
# 1/1 [==============================] - 0s 20ms/step
# 350/350 [==============================] - 2s 5ms/step
# 1/1 [==============================] - 0s 31ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4416 - mse: 0.2010 - cindex_score: 0.8630
# Epoch 2/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4433 - mse: 0.2016 - cindex_score: 0.8622
# Epoch 3/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4318 - mse: 0.1911 - cindex_score: 0.8668
# Epoch 4/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4336 - mse: 0.1910 - cindex_score: 0.8574
# Epoch 5/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4304 - mse: 0.1905 - cindex_score: 0.8602
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4269 - mse: 0.1872 - cindex_score: 0.8588
# Epoch 7/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3973 - mse: 0.1527 - cindex_score: 0.8683
# Epoch 8/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4248 - mse: 0.1834 - cindex_score: 0.8658
# Epoch 9/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4259 - mse: 0.1891 - cindex_score: 0.8606
# Epoch 10/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3997 - mse: 0.1597 - cindex_score: 0.8658
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4170 - mse: 0.1709 - cindex_score: 0.8717
# Epoch 12/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3693 - mse: 0.1270 - cindex_score: 0.8856
# Epoch 13/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4101 - mse: 0.1653 - cindex_score: 0.8654
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4048 - mse: 0.1649 - cindex_score: 0.8666
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4121 - mse: 0.1738 - cindex_score: 0.8636
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3808 - mse: 0.1385 - cindex_score: 0.8678
# Epoch 17/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3699 - mse: 0.1275 - cindex_score: 0.8838
# Epoch 18/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3647 - mse: 0.1228 - cindex_score: 0.8860
# Epoch 19/20
# 1/1 [==============================] - 1s 838ms/step - loss: 0.3752 - mse: 0.1339 - cindex_score: 0.8803
# Epoch 20/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3855 - mse: 0.1449 - cindex_score: 0.8761
# 1/1 [==============================] - 0s 293ms/step
# 350/350 [==============================] - 2s 4ms/step
# 1/1 [==============================] - 0s 35ms/step
# Epoch 1/20
# 1/1 [==============================] - 1s 742ms/step - loss: 0.3652 - mse: 0.1606 - cindex_score: 0.8897
# Epoch 2/20
# 1/1 [==============================] - 1s 894ms/step - loss: 0.3865 - mse: 0.1995 - cindex_score: 0.8691
# Epoch 3/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3854 - mse: 0.2034 - cindex_score: 0.8677
# Epoch 4/20
# 1/1 [==============================] - 0s 273ms/step - loss: 0.3751 - mse: 0.2165 - cindex_score: 0.8621
# Epoch 5/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3913 - mse: 0.2086 - cindex_score: 0.8647
# Epoch 6/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3973 - mse: 0.2102 - cindex_score: 0.8671
# Epoch 7/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3852 - mse: 0.2148 - cindex_score: 0.8703
# Epoch 8/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3974 - mse: 0.2059 - cindex_score: 0.8663
# Epoch 9/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3821 - mse: 0.2018 - cindex_score: 0.8655
# Epoch 10/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3576 - mse: 0.1686 - cindex_score: 0.8804
# Epoch 11/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3906 - mse: 0.2149 - cindex_score: 0.8619
# Epoch 12/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3877 - mse: 0.2043 - cindex_score: 0.8679
# Epoch 13/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3577 - mse: 0.1755 - cindex_score: 0.8810
# Epoch 14/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3993 - mse: 0.2250 - cindex_score: 0.8633
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3969 - mse: 0.2123 - cindex_score: 0.8615
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3733 - mse: 0.1875 - cindex_score: 0.8705
# Epoch 17/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3558 - mse: 0.1745 - cindex_score: 0.8871
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3692 - mse: 0.1797 - cindex_score: 0.8758
# Epoch 19/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3564 - mse: 0.1785 - cindex_score: 0.8903
# Epoch 20/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3729 - mse: 0.1880 - cindex_score: 0.8736
# 1/1 [==============================] - 0s 19ms/step
# 350/350 [==============================] - 2s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4510 - mse: 0.2041 - cindex_score: 0.8413
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4805 - mse: 0.2340 - cindex_score: 0.8411
# Epoch 3/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4648 - mse: 0.2172 - cindex_score: 0.8487
# Epoch 4/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4311 - mse: 0.1840 - cindex_score: 0.8572
# Epoch 5/20
# 1/1 [==============================] - 1s 841ms/step - loss: 0.4310 - mse: 0.1838 - cindex_score: 0.8506
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4538 - mse: 0.2081 - cindex_score: 0.8419
# Epoch 7/20
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4302 - mse: 0.1840 - cindex_score: 0.8634
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4445 - mse: 0.1990 - cindex_score: 0.8405
# Epoch 9/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4283 - mse: 0.1813 - cindex_score: 0.8653
# Epoch 10/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4196 - mse: 0.1726 - cindex_score: 0.8588
# Epoch 11/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4097 - mse: 0.1650 - cindex_score: 0.8608
# Epoch 12/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4074 - mse: 0.1615 - cindex_score: 0.8616
# Epoch 13/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3891 - mse: 0.1418 - cindex_score: 0.8687
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4058 - mse: 0.1609 - cindex_score: 0.8642
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4081 - mse: 0.1632 - cindex_score: 0.8737
# Epoch 16/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4091 - mse: 0.1625 - cindex_score: 0.8592
# Epoch 17/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3823 - mse: 0.1363 - cindex_score: 0.8651
# Epoch 18/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3828 - mse: 0.1361 - cindex_score: 0.8687
# Epoch 19/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3818 - mse: 0.1353 - cindex_score: 0.8636
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3798 - mse: 0.1327 - cindex_score: 0.8689
# 1/1 [==============================] - 0s 20ms/step
# 350/350 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 1s 783ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 322ms/step - loss: 0.3730 - mse: 0.1346 - cindex_score: 0.8768
# Epoch 2/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3876 - mse: 0.1547 - cindex_score: 0.8701
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3506 - mse: 0.1150 - cindex_score: 0.8871
# Epoch 4/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3537 - mse: 0.1094 - cindex_score: 0.8961
# Epoch 5/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3675 - mse: 0.1280 - cindex_score: 0.8881
# Epoch 6/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3792 - mse: 0.1400 - cindex_score: 0.8754
# Epoch 7/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3697 - mse: 0.1332 - cindex_score: 0.8899
# Epoch 8/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3823 - mse: 0.1432 - cindex_score: 0.8760
# Epoch 9/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3677 - mse: 0.1273 - cindex_score: 0.8858
# Epoch 10/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3725 - mse: 0.1308 - cindex_score: 0.8834
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3599 - mse: 0.1173 - cindex_score: 0.8897
# Epoch 12/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3803 - mse: 0.1433 - cindex_score: 0.8730
# Epoch 13/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3832 - mse: 0.1415 - cindex_score: 0.8762
# Epoch 14/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3650 - mse: 0.1225 - cindex_score: 0.8865
# Epoch 15/20
# 1/1 [==============================] - 0s 229ms/step - loss: 0.3537 - mse: 0.1137 - cindex_score: 0.8860
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3678 - mse: 0.1302 - cindex_score: 0.8808
# Epoch 17/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3504 - mse: 0.1110 - cindex_score: 0.8955
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3697 - mse: 0.1330 - cindex_score: 0.8756
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3546 - mse: 0.1126 - cindex_score: 0.8951
# Epoch 20/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3536 - mse: 0.1102 - cindex_score: 0.8891
# 1/1 [==============================] - 0s 26ms/step
# 350/350 [==============================] - 3s 9ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 370ms/step - loss: 0.4346 - mse: 0.1989 - cindex_score: 0.8762
# Epoch 2/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4088 - mse: 0.1745 - cindex_score: 0.8879
# Epoch 3/20
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3778 - mse: 0.1438 - cindex_score: 0.8871
# Epoch 4/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3844 - mse: 0.1456 - cindex_score: 0.8857
# Epoch 5/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3709 - mse: 0.1333 - cindex_score: 0.8984
# Epoch 6/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3941 - mse: 0.1563 - cindex_score: 0.9018
# Epoch 7/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3955 - mse: 0.1566 - cindex_score: 0.8885
# Epoch 8/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3709 - mse: 0.1324 - cindex_score: 0.8907
# Epoch 9/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3539 - mse: 0.1152 - cindex_score: 0.9004
# Epoch 10/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3431 - mse: 0.1046 - cindex_score: 0.9107
# Epoch 11/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3783 - mse: 0.1446 - cindex_score: 0.8990
# Epoch 12/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3773 - mse: 0.1412 - cindex_score: 0.8984
# Epoch 13/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3499 - mse: 0.1145 - cindex_score: 0.9072
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3611 - mse: 0.1208 - cindex_score: 0.8996
# Epoch 15/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3707 - mse: 0.1340 - cindex_score: 0.8976
# Epoch 16/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3528 - mse: 0.1195 - cindex_score: 0.9018
# Epoch 17/20
# 1/1 [==============================] - 1s 883ms/step - loss: 0.3611 - mse: 0.1202 - cindex_score: 0.8990
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3585 - mse: 0.1178 - cindex_score: 0.9119
# Epoch 19/20
# 1/1 [==============================] - 0s 283ms/step - loss: 0.3511 - mse: 0.1147 - cindex_score: 0.9048
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3710 - mse: 0.1394 - cindex_score: 0.9004
# 1/1 [==============================] - 0s 18ms/step
# 350/350 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3726 - mse: 0.1812 - cindex_score: 0.8750
# Epoch 2/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4018 - mse: 0.2120 - cindex_score: 0.8585
# Epoch 3/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3797 - mse: 0.1855 - cindex_score: 0.8712
# Epoch 4/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3983 - mse: 0.2159 - cindex_score: 0.8617
# Epoch 5/20
# 1/1 [==============================] - 1s 891ms/step - loss: 0.4012 - mse: 0.2193 - cindex_score: 0.8654
# Epoch 6/20
# 1/1 [==============================] - 0s 290ms/step - loss: 0.3678 - mse: 0.1759 - cindex_score: 0.8821
# Epoch 7/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3831 - mse: 0.1914 - cindex_score: 0.8647
# Epoch 8/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3690 - mse: 0.1747 - cindex_score: 0.8698
# Epoch 9/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3695 - mse: 0.1856 - cindex_score: 0.8750
# Epoch 10/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3462 - mse: 0.1627 - cindex_score: 0.8813
# Epoch 11/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3675 - mse: 0.1772 - cindex_score: 0.8728
# Epoch 12/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3437 - mse: 0.1449 - cindex_score: 0.8926
# Epoch 13/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3487 - mse: 0.1728 - cindex_score: 0.8901
# Epoch 14/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3635 - mse: 0.2057 - cindex_score: 0.8732
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3357 - mse: 0.1600 - cindex_score: 0.8964
# Epoch 16/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3438 - mse: 0.1595 - cindex_score: 0.8889
# Epoch 17/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3524 - mse: 0.1674 - cindex_score: 0.8859
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3371 - mse: 0.1641 - cindex_score: 0.8916
# Epoch 19/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3439 - mse: 0.1651 - cindex_score: 0.8903
# Epoch 20/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3301 - mse: 0.1554 - cindex_score: 0.8996
# 1/1 [==============================] - 0s 19ms/step
# 350/350 [==============================] - 2s 5ms/step
# 1/1 [==============================] - 1s 777ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 279ms/step - loss: 0.4287 - mse: 0.2157 - cindex_score: 0.8801
# Epoch 2/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4222 - mse: 0.2142 - cindex_score: 0.8755
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4084 - mse: 0.2073 - cindex_score: 0.8735
# Epoch 4/20
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3866 - mse: 0.2154 - cindex_score: 0.8683
# Epoch 5/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3842 - mse: 0.1876 - cindex_score: 0.8848
# Epoch 6/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4040 - mse: 0.2183 - cindex_score: 0.8813
# Epoch 7/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4116 - mse: 0.2160 - cindex_score: 0.8723
# Epoch 8/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4070 - mse: 0.2157 - cindex_score: 0.8733
# Epoch 9/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3959 - mse: 0.1990 - cindex_score: 0.8771
# Epoch 10/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3548 - mse: 0.1549 - cindex_score: 0.8952
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3652 - mse: 0.1547 - cindex_score: 0.8864
# Epoch 12/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3751 - mse: 0.1758 - cindex_score: 0.8842
# Epoch 13/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3932 - mse: 0.1847 - cindex_score: 0.8797
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3842 - mse: 0.1735 - cindex_score: 0.8860
# Epoch 15/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3664 - mse: 0.1719 - cindex_score: 0.8840
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3767 - mse: 0.1819 - cindex_score: 0.8846
# Epoch 17/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3656 - mse: 0.1534 - cindex_score: 0.8860
# Epoch 18/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3774 - mse: 0.1667 - cindex_score: 0.8819
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3626 - mse: 0.1672 - cindex_score: 0.8908
# Epoch 20/20
# 1/1 [==============================] - 1s 833ms/step - loss: 0.3604 - mse: 0.1724 - cindex_score: 0.8900
# 1/1 [==============================] - 0s 261ms/step
# 350/350 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 28ms/step
# Epoch 1/20
# 1/1 [==============================] - 1s 875ms/step - loss: 0.4245 - mse: 0.1863 - cindex_score: 0.8728
# Epoch 2/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4431 - mse: 0.2061 - cindex_score: 0.8562
# Epoch 3/20
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4248 - mse: 0.1848 - cindex_score: 0.8655
# Epoch 4/20
# 1/1 [==============================] - 1s 856ms/step - loss: 0.4254 - mse: 0.1922 - cindex_score: 0.8619
# Epoch 5/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3980 - mse: 0.1627 - cindex_score: 0.8832
# Epoch 6/20
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4450 - mse: 0.2053 - cindex_score: 0.8653
# Epoch 7/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4170 - mse: 0.1784 - cindex_score: 0.8675
# Epoch 8/20
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4405 - mse: 0.2062 - cindex_score: 0.8500
# Epoch 9/20
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4229 - mse: 0.1898 - cindex_score: 0.8566
# Epoch 10/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4083 - mse: 0.1681 - cindex_score: 0.8671
# Epoch 11/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4344 - mse: 0.1962 - cindex_score: 0.8596
# Epoch 12/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4217 - mse: 0.1854 - cindex_score: 0.8732
# Epoch 13/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4171 - mse: 0.1866 - cindex_score: 0.8669
# Epoch 14/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4212 - mse: 0.1841 - cindex_score: 0.8661
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3805 - mse: 0.1426 - cindex_score: 0.8766
# Epoch 16/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4071 - mse: 0.1708 - cindex_score: 0.8681
# Epoch 17/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4158 - mse: 0.1817 - cindex_score: 0.8619
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3713 - mse: 0.1302 - cindex_score: 0.8909
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4041 - mse: 0.1673 - cindex_score: 0.8651
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3660 - mse: 0.1327 - cindex_score: 0.8907
# 1/1 [==============================] - 1s 587ms/step
# 350/350 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 1s 684ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 313ms/step - loss: 0.4612 - mse: 0.2352 - cindex_score: 0.8414
# Epoch 2/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4563 - mse: 0.2251 - cindex_score: 0.8524
# Epoch 3/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4614 - mse: 0.2301 - cindex_score: 0.8383
# Epoch 4/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4413 - mse: 0.2097 - cindex_score: 0.8545
# Epoch 5/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4478 - mse: 0.2155 - cindex_score: 0.8577
# Epoch 6/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4727 - mse: 0.2411 - cindex_score: 0.8466
# Epoch 7/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4613 - mse: 0.2214 - cindex_score: 0.8498
# Epoch 8/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4447 - mse: 0.2079 - cindex_score: 0.8571
# Epoch 9/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4423 - mse: 0.2073 - cindex_score: 0.8496
# Epoch 10/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4581 - mse: 0.2228 - cindex_score: 0.8541
# Epoch 11/20
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4086 - mse: 0.1731 - cindex_score: 0.8662
# Epoch 12/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4302 - mse: 0.1959 - cindex_score: 0.8524
# Epoch 13/20
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4117 - mse: 0.1733 - cindex_score: 0.8722
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4393 - mse: 0.2018 - cindex_score: 0.8549
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4278 - mse: 0.1888 - cindex_score: 0.8565
# Epoch 16/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4282 - mse: 0.1925 - cindex_score: 0.8555
# Epoch 17/20
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4055 - mse: 0.1671 - cindex_score: 0.8654
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4078 - mse: 0.1689 - cindex_score: 0.8702
# Epoch 19/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4025 - mse: 0.1657 - cindex_score: 0.8724
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4259 - mse: 0.1896 - cindex_score: 0.8557
# 1/1 [==============================] - 0s 21ms/step
# 350/350 [==============================] - 2s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4126 - mse: 0.1752 - cindex_score: 0.8708
# Epoch 2/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4244 - mse: 0.1878 - cindex_score: 0.8567
# Epoch 3/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4213 - mse: 0.1834 - cindex_score: 0.8629
# Epoch 4/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4302 - mse: 0.1905 - cindex_score: 0.8579
# Epoch 5/20
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3987 - mse: 0.1628 - cindex_score: 0.8811
# Epoch 6/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4000 - mse: 0.1605 - cindex_score: 0.8746
# Epoch 7/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4191 - mse: 0.1808 - cindex_score: 0.8668
# Epoch 8/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3856 - mse: 0.1448 - cindex_score: 0.8819
# Epoch 9/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3970 - mse: 0.1576 - cindex_score: 0.8736
# Epoch 10/20
# 1/1 [==============================] - 1s 878ms/step - loss: 0.3931 - mse: 0.1550 - cindex_score: 0.8768
# Epoch 11/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3821 - mse: 0.1470 - cindex_score: 0.8841
# Epoch 12/20
# 1/1 [==============================] - 0s 317ms/step - loss: 0.3831 - mse: 0.1508 - cindex_score: 0.8776
# Epoch 13/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3598 - mse: 0.1236 - cindex_score: 0.8825
# Epoch 14/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3771 - mse: 0.1414 - cindex_score: 0.8801
# Epoch 15/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3807 - mse: 0.1421 - cindex_score: 0.8712
# Epoch 16/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3596 - mse: 0.1227 - cindex_score: 0.8873
# Epoch 17/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3720 - mse: 0.1335 - cindex_score: 0.8851
# Epoch 18/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3900 - mse: 0.1526 - cindex_score: 0.8738
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3456 - mse: 0.1081 - cindex_score: 0.8992
# Epoch 20/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3695 - mse: 0.1350 - cindex_score: 0.8803
# 1/1 [==============================] - 0s 29ms/step
# 350/350 [==============================] - 3s 8ms/step
# 1/1 [==============================] - 0s 480ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4507 - mse: 0.2864 - cindex_score: 0.8528
# Epoch 2/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4399 - mse: 0.2735 - cindex_score: 0.8522
# Epoch 3/20
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3994 - mse: 0.2529 - cindex_score: 0.8777
# Epoch 4/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4327 - mse: 0.2736 - cindex_score: 0.8524
# Epoch 5/20
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4129 - mse: 0.2383 - cindex_score: 0.8697
# Epoch 6/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4256 - mse: 0.2645 - cindex_score: 0.8568
# Epoch 7/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4222 - mse: 0.2508 - cindex_score: 0.8640
# Epoch 8/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4391 - mse: 0.2640 - cindex_score: 0.8594
# Epoch 9/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4175 - mse: 0.2479 - cindex_score: 0.8685
# Epoch 10/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4068 - mse: 0.2406 - cindex_score: 0.8743
# Epoch 11/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3886 - mse: 0.2380 - cindex_score: 0.8749
# Epoch 12/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3981 - mse: 0.2352 - cindex_score: 0.8701
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4063 - mse: 0.2379 - cindex_score: 0.8677
# Epoch 14/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3966 - mse: 0.2405 - cindex_score: 0.8721
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3995 - mse: 0.2441 - cindex_score: 0.8695
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4007 - mse: 0.2514 - cindex_score: 0.8715
# Epoch 17/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3751 - mse: 0.1940 - cindex_score: 0.8868
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3992 - mse: 0.2331 - cindex_score: 0.8854
# Epoch 19/20
# 1/1 [==============================] - 1s 822ms/step - loss: 0.3867 - mse: 0.2122 - cindex_score: 0.8826
# Epoch 20/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3822 - mse: 0.2182 - cindex_score: 0.8765
# 1/1 [==============================] - 0s 260ms/step
# 350/350 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5128 - mse: 0.2806 - cindex_score: 0.8590
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5031 - mse: 0.2702 - cindex_score: 0.8522
# Epoch 3/20
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4295 - mse: 0.2020 - cindex_score: 0.8490
# Epoch 4/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4212 - mse: 0.1894 - cindex_score: 0.8532
# Epoch 5/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4171 - mse: 0.2020 - cindex_score: 0.8605
# Epoch 6/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4503 - mse: 0.2232 - cindex_score: 0.8615
# Epoch 7/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4453 - mse: 0.2225 - cindex_score: 0.8600
# Epoch 8/20
# 1/1 [==============================] - 1s 821ms/step - loss: 0.4256 - mse: 0.2163 - cindex_score: 0.8617
# Epoch 9/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4195 - mse: 0.1886 - cindex_score: 0.8490
# Epoch 10/20
# 1/1 [==============================] - 0s 288ms/step - loss: 0.3773 - mse: 0.1509 - cindex_score: 0.8701
# Epoch 11/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3964 - mse: 0.1684 - cindex_score: 0.8562
# Epoch 12/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4071 - mse: 0.1763 - cindex_score: 0.8615
# Epoch 13/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3902 - mse: 0.1575 - cindex_score: 0.8735
# Epoch 14/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4075 - mse: 0.1734 - cindex_score: 0.8584
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3811 - mse: 0.1453 - cindex_score: 0.8681
# Epoch 16/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3890 - mse: 0.1695 - cindex_score: 0.8584
# Epoch 17/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3873 - mse: 0.1567 - cindex_score: 0.8615
# Epoch 18/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3822 - mse: 0.1577 - cindex_score: 0.8657
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4126 - mse: 0.1827 - cindex_score: 0.8554
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3831 - mse: 0.1558 - cindex_score: 0.8725
# 1/1 [==============================] - 0s 30ms/step
# 350/350 [==============================] - 5s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4643 - mse: 0.2264 - cindex_score: 0.8626
# Epoch 2/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4207 - mse: 0.1821 - cindex_score: 0.8711
# Epoch 3/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4158 - mse: 0.1745 - cindex_score: 0.8660
# Epoch 4/20
# 1/1 [==============================] - 0s 242ms/step - loss: 0.4201 - mse: 0.1789 - cindex_score: 0.8747
# Epoch 5/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4440 - mse: 0.2029 - cindex_score: 0.8745
# Epoch 6/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4441 - mse: 0.2028 - cindex_score: 0.8668
# Epoch 7/20
# 1/1 [==============================] - 1s 703ms/step - loss: 0.4242 - mse: 0.1832 - cindex_score: 0.8701
# Epoch 8/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3815 - mse: 0.1405 - cindex_score: 0.8832
# Epoch 9/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3723 - mse: 0.1324 - cindex_score: 0.8809
# Epoch 10/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3683 - mse: 0.1273 - cindex_score: 0.8787
# Epoch 11/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3782 - mse: 0.1398 - cindex_score: 0.8771
# Epoch 12/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4029 - mse: 0.1625 - cindex_score: 0.8767
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3814 - mse: 0.1412 - cindex_score: 0.8862
# Epoch 14/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3656 - mse: 0.1273 - cindex_score: 0.8819
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3598 - mse: 0.1190 - cindex_score: 0.8826
# Epoch 16/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3654 - mse: 0.1246 - cindex_score: 0.8840
# Epoch 17/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3479 - mse: 0.1078 - cindex_score: 0.8906
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3475 - mse: 0.1067 - cindex_score: 0.9037
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3568 - mse: 0.1167 - cindex_score: 0.8886
# Epoch 20/20
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3405 - mse: 0.1013 - cindex_score: 0.8948
# 1/1 [==============================] - 0s 18ms/step
# 350/350 [==============================] - 2s 6ms/step
# 1/1 [==============================] - 1s 702ms/step
# Epoch 1/20
# 1/1 [==============================] - 1s 894ms/step - loss: 0.3959 - mse: 0.1841 - cindex_score: 0.8668
# Epoch 2/20
# 1/1 [==============================] - 1s 889ms/step - loss: 0.3720 - mse: 0.1686 - cindex_score: 0.8781
# Epoch 3/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3724 - mse: 0.1632 - cindex_score: 0.8723
# Epoch 4/20
# 1/1 [==============================] - 0s 322ms/step - loss: 0.3584 - mse: 0.1587 - cindex_score: 0.8799
# Epoch 5/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3895 - mse: 0.1875 - cindex_score: 0.8658
# Epoch 6/20
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3832 - mse: 0.1840 - cindex_score: 0.8670
# Epoch 7/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3787 - mse: 0.1782 - cindex_score: 0.8592
# Epoch 8/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3698 - mse: 0.1656 - cindex_score: 0.8692
# Epoch 9/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3774 - mse: 0.1738 - cindex_score: 0.8717
# Epoch 10/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3997 - mse: 0.1971 - cindex_score: 0.8590
# Epoch 11/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3765 - mse: 0.1751 - cindex_score: 0.8704
# Epoch 12/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3750 - mse: 0.1621 - cindex_score: 0.8753
# Epoch 13/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3863 - mse: 0.2072 - cindex_score: 0.8624
# Epoch 14/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3726 - mse: 0.1886 - cindex_score: 0.8664
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3620 - mse: 0.1619 - cindex_score: 0.8747
# Epoch 16/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3540 - mse: 0.1497 - cindex_score: 0.8789
# Epoch 17/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3650 - mse: 0.1620 - cindex_score: 0.8882
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3504 - mse: 0.1552 - cindex_score: 0.8761
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3693 - mse: 0.1660 - cindex_score: 0.8725
# Epoch 20/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3592 - mse: 0.1474 - cindex_score: 0.8747
# 1/1 [==============================] - 0s 436ms/step
# 350/350 [==============================] - 5s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3853 - mse: 0.1471 - cindex_score: 0.8934
# Epoch 2/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4202 - mse: 0.1800 - cindex_score: 0.8803
# Epoch 3/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3887 - mse: 0.1487 - cindex_score: 0.8822
# Epoch 4/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3671 - mse: 0.1272 - cindex_score: 0.8924
# Epoch 5/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3824 - mse: 0.1423 - cindex_score: 0.8840
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3852 - mse: 0.1454 - cindex_score: 0.8904
# Epoch 7/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3759 - mse: 0.1362 - cindex_score: 0.8894
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3532 - mse: 0.1132 - cindex_score: 0.8900
# Epoch 9/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3766 - mse: 0.1367 - cindex_score: 0.8866
# Epoch 10/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3797 - mse: 0.1401 - cindex_score: 0.8910
# Epoch 11/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3575 - mse: 0.1180 - cindex_score: 0.8965
# Epoch 12/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3537 - mse: 0.1139 - cindex_score: 0.9029
# Epoch 13/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3543 - mse: 0.1147 - cindex_score: 0.8932
# Epoch 14/20
# 1/1 [==============================] - 0s 229ms/step - loss: 0.3478 - mse: 0.1088 - cindex_score: 0.8993
# Epoch 15/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3536 - mse: 0.1140 - cindex_score: 0.8914
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3496 - mse: 0.1099 - cindex_score: 0.8961
# Epoch 17/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3381 - mse: 0.0984 - cindex_score: 0.8963
# Epoch 18/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3355 - mse: 0.0959 - cindex_score: 0.8965
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3284 - mse: 0.0890 - cindex_score: 0.9065
# Epoch 20/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3435 - mse: 0.1045 - cindex_score: 0.9001
# 1/1 [==============================] - 0s 18ms/step
# 350/350 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 1s 718ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4853 - mse: 0.2814 - cindex_score: 0.8724
# Epoch 2/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4408 - mse: 0.2252 - cindex_score: 0.8694
# Epoch 3/20
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4284 - mse: 0.2233 - cindex_score: 0.8593
# Epoch 4/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4060 - mse: 0.2167 - cindex_score: 0.8575
# Epoch 5/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3905 - mse: 0.1966 - cindex_score: 0.8680
# Epoch 6/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4419 - mse: 0.2672 - cindex_score: 0.8652
# Epoch 7/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4339 - mse: 0.2331 - cindex_score: 0.8712
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4065 - mse: 0.2163 - cindex_score: 0.8813
# Epoch 9/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4059 - mse: 0.2216 - cindex_score: 0.8670
# Epoch 10/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3836 - mse: 0.1867 - cindex_score: 0.8775
# Epoch 11/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4014 - mse: 0.2041 - cindex_score: 0.8656
# Epoch 12/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3998 - mse: 0.2085 - cindex_score: 0.8648
# Epoch 13/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4022 - mse: 0.1954 - cindex_score: 0.8742
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4173 - mse: 0.2123 - cindex_score: 0.8638
# Epoch 15/20
# 1/1 [==============================] - 0s 230ms/step - loss: 0.3957 - mse: 0.1903 - cindex_score: 0.8746
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3897 - mse: 0.1985 - cindex_score: 0.8746
# Epoch 17/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3595 - mse: 0.1741 - cindex_score: 0.8886
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4011 - mse: 0.1949 - cindex_score: 0.8704
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3799 - mse: 0.1851 - cindex_score: 0.8761
# Epoch 20/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3636 - mse: 0.1713 - cindex_score: 0.8920
# 1/1 [==============================] - 0s 21ms/step
# 350/350 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4209 - mse: 0.2340 - cindex_score: 0.8776
# Epoch 2/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4571 - mse: 0.2677 - cindex_score: 0.8480
# Epoch 3/20
# 1/1 [==============================] - 1s 864ms/step - loss: 0.4329 - mse: 0.2432 - cindex_score: 0.8654
# Epoch 4/20
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4070 - mse: 0.2151 - cindex_score: 0.8758
# Epoch 5/20
# 1/1 [==============================] - 0s 327ms/step - loss: 0.4220 - mse: 0.2181 - cindex_score: 0.8684
# Epoch 6/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4246 - mse: 0.2347 - cindex_score: 0.8668
# Epoch 7/20
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4055 - mse: 0.2132 - cindex_score: 0.8736
# Epoch 8/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4194 - mse: 0.2257 - cindex_score: 0.8653
# Epoch 9/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4004 - mse: 0.2013 - cindex_score: 0.8734
# Epoch 10/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4063 - mse: 0.2116 - cindex_score: 0.8694
# Epoch 11/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4242 - mse: 0.2353 - cindex_score: 0.8609
# Epoch 12/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3792 - mse: 0.1880 - cindex_score: 0.8827
# Epoch 13/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3803 - mse: 0.2039 - cindex_score: 0.8776
# Epoch 14/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3905 - mse: 0.2121 - cindex_score: 0.8700
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4096 - mse: 0.2275 - cindex_score: 0.8668
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3708 - mse: 0.1707 - cindex_score: 0.8897
# Epoch 17/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3961 - mse: 0.2284 - cindex_score: 0.8700
# Epoch 18/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3855 - mse: 0.2153 - cindex_score: 0.8738
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3703 - mse: 0.1911 - cindex_score: 0.8849
# Epoch 20/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3915 - mse: 0.2207 - cindex_score: 0.8722
# 1/1 [==============================] - 0s 35ms/step
# 350/350 [==============================] - 2s 5ms/step
# 1/1 [==============================] - 0s 422ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3609 - mse: 0.1633 - cindex_score: 0.8894
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3811 - mse: 0.1762 - cindex_score: 0.8702
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3528 - mse: 0.1592 - cindex_score: 0.8821
# Epoch 4/20
# 1/1 [==============================] - 1s 753ms/step - loss: 0.3504 - mse: 0.1503 - cindex_score: 0.8860
# Epoch 5/20
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3533 - mse: 0.1667 - cindex_score: 0.8819
# Epoch 6/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3590 - mse: 0.1548 - cindex_score: 0.8835
# Epoch 7/20
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3592 - mse: 0.1657 - cindex_score: 0.8823
# Epoch 8/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3631 - mse: 0.1699 - cindex_score: 0.8880
# Epoch 9/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3448 - mse: 0.1401 - cindex_score: 0.8906
# Epoch 10/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3557 - mse: 0.1631 - cindex_score: 0.8845
# Epoch 11/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3560 - mse: 0.1597 - cindex_score: 0.8797
# Epoch 12/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3645 - mse: 0.1749 - cindex_score: 0.8777
# Epoch 13/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3553 - mse: 0.1533 - cindex_score: 0.8886
# Epoch 14/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3534 - mse: 0.1570 - cindex_score: 0.8829
# Epoch 15/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3346 - mse: 0.1348 - cindex_score: 0.9015
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3408 - mse: 0.1637 - cindex_score: 0.8900
# Epoch 17/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3403 - mse: 0.1468 - cindex_score: 0.8928
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3427 - mse: 0.1367 - cindex_score: 0.8964
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3494 - mse: 0.1463 - cindex_score: 0.8894
# Epoch 20/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3344 - mse: 0.1311 - cindex_score: 0.8916
# 1/1 [==============================] - 0s 298ms/step
# 350/350 [==============================] - 2s 5ms/step
# 1/1 [==============================] - 0s 337ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 335ms/step - loss: 0.4029 - mse: 0.1784 - cindex_score: 0.8749
# Epoch 2/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3985 - mse: 0.1689 - cindex_score: 0.8725
# Epoch 3/20
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4006 - mse: 0.1745 - cindex_score: 0.8725
# Epoch 4/20
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3975 - mse: 0.1703 - cindex_score: 0.8721
# Epoch 5/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4020 - mse: 0.1705 - cindex_score: 0.8678
# Epoch 6/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3892 - mse: 0.1580 - cindex_score: 0.8699
# Epoch 7/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4009 - mse: 0.1686 - cindex_score: 0.8693
# Epoch 8/20
# ...
# Epoch 16/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3057 - mse: 0.1746 - cindex_score: 0.9000
# Epoch 17/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3420 - mse: 0.2002 - cindex_score: 0.8970
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3269 - mse: 0.2027 - cindex_score: 0.8963
# Epoch 19/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3223 - mse: 0.1743 - cindex_score: 0.8915
# Epoch 20/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3313 - mse: 0.1904 - cindex_score: 0.8907
# 1/1 [==============================] - 0s 28ms/step
# 350/350 [==============================] - 2s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4455 - mse: 0.2526 - cindex_score: 0.8782
# Epoch 2/20
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3656 - mse: 0.1703 - cindex_score: 0.8757
# Epoch 3/20
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3086 - mse: 0.1163 - cindex_score: 0.8840
# Epoch 4/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3430 - mse: 0.1556 - cindex_score: 0.8826
# Epoch 5/20
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3860 - mse: 0.2004 - cindex_score: 0.8858
# Epoch 6/20
# 1/1 [==============================] - 1s 851ms/step - loss: 0.4196 - mse: 0.2316 - cindex_score: 0.8852
# Epoch 7/20
# 1/1 [==============================] - 0s 306ms/step - loss: 0.3760 - mse: 0.1962 - cindex_score: 0.8808
# Epoch 8/20
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3229 - mse: 0.1320 - cindex_score: 0.8947
# Epoch 9/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3301 - mse: 0.1373 - cindex_score: 0.8790
# Epoch 10/20
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3098 - mse: 0.1188 - cindex_score: 0.8810
# Epoch 11/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3338 - mse: 0.1377 - cindex_score: 0.8923
# Epoch 12/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3683 - mse: 0.1744 - cindex_score: 0.8915
# Epoch 13/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3370 - mse: 0.1400 - cindex_score: 0.8955
# Epoch 14/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3088 - mse: 0.1180 - cindex_score: 0.8878
# Epoch 15/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2891 - mse: 0.1037 - cindex_score: 0.8979
# Epoch 16/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3060 - mse: 0.1155 - cindex_score: 0.8917
# Epoch 17/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3221 - mse: 0.1412 - cindex_score: 0.8842
# Epoch 18/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3379 - mse: 0.1428 - cindex_score: 0.8848
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3103 - mse: 0.1297 - cindex_score: 0.8872
# Epoch 20/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3060 - mse: 0.1188 - cindex_score: 0.8860
# 1/1 [==============================] - 0s 248ms/step
# 350/350 [==============================] - 3s 8ms/step
# 1/1 [==============================] - 0s 493ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3474 - mse: 0.1511 - cindex_score: 0.8794
# Epoch 2/20
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3325 - mse: 0.1291 - cindex_score: 0.8808
# Epoch 3/20
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3404 - mse: 0.1354 - cindex_score: 0.8819
# Epoch 4/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3557 - mse: 0.1507 - cindex_score: 0.8841
# Epoch 5/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3684 - mse: 0.1631 - cindex_score: 0.8770
# Epoch 6/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3299 - mse: 0.1277 - cindex_score: 0.8875
# Epoch 7/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2970 - mse: 0.0970 - cindex_score: 0.9010
# Epoch 8/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3124 - mse: 0.1145 - cindex_score: 0.8879
# Epoch 9/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3076 - mse: 0.1068 - cindex_score: 0.9052
# Epoch 10/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3242 - mse: 0.1222 - cindex_score: 0.8921
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3132 - mse: 0.1152 - cindex_score: 0.8962
# Epoch 12/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3080 - mse: 0.1070 - cindex_score: 0.8970
# Epoch 13/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3204 - mse: 0.1192 - cindex_score: 0.8889
# Epoch 14/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3032 - mse: 0.1025 - cindex_score: 0.8964
# Epoch 15/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3038 - mse: 0.1007 - cindex_score: 0.8942
# Epoch 16/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2893 - mse: 0.0873 - cindex_score: 0.9062
# Epoch 17/20
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2895 - mse: 0.0892 - cindex_score: 0.9018
# Epoch 18/20
# 1/1 [==============================] - 1s 923ms/step - loss: 0.2889 - mse: 0.0887 - cindex_score: 0.9063
# Epoch 19/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3096 - mse: 0.1078 - cindex_score: 0.8921
# Epoch 20/20
# 1/1 [==============================] - 0s 317ms/step - loss: 0.2951 - mse: 0.0949 - cindex_score: 0.9071
# 1/1 [==============================] - 0s 33ms/step
# 350/350 [==============================] - 3s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/20
# 1/1 [==============================] - 0s 76ms/step - loss: 0.3386 - mse: 0.2409 - cindex_score: 0.8728
# Epoch 2/20
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3142 - mse: 0.2095 - cindex_score: 0.8873
# Epoch 3/20
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3359 - mse: 0.2330 - cindex_score: 0.8792
# Epoch 4/20
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3535 - mse: 0.2689 - cindex_score: 0.8623
# Epoch 5/20
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3524 - mse: 0.2616 - cindex_score: 0.8706
# Epoch 6/20
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3305 - mse: 0.2294 - cindex_score: 0.8776
# Epoch 7/20
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3143 - mse: 0.2128 - cindex_score: 0.8927
# Epoch 8/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3271 - mse: 0.2212 - cindex_score: 0.8736
# Epoch 9/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3374 - mse: 0.2322 - cindex_score: 0.8710
# Epoch 10/20
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3299 - mse: 0.2240 - cindex_score: 0.8706
# Epoch 11/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3240 - mse: 0.2110 - cindex_score: 0.8724
# Epoch 12/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3233 - mse: 0.2155 - cindex_score: 0.8744
# Epoch 13/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2985 - mse: 0.2033 - cindex_score: 0.8903
# Epoch 14/20
# 1/1 [==============================] - 0s 333ms/step - loss: 0.3172 - mse: 0.2116 - cindex_score: 0.8764
# Epoch 15/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3022 - mse: 0.1893 - cindex_score: 0.8788
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2958 - mse: 0.2072 - cindex_score: 0.8855
# Epoch 17/20
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2978 - mse: 0.2020 - cindex_score: 0.8851
# Epoch 18/20
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3191 - mse: 0.2146 - cindex_score: 0.8718
# Epoch 19/20
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3117 - mse: 0.2326 - cindex_score: 0.8732
# Epoch 20/20
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2885 - mse: 0.1748 - cindex_score: 0.8863
# 1/1 [==============================] - 0s 39ms/step
# 350/350 [==============================] - 3s 9ms/step
# 1/1 [==============================] - 0s 18ms/step
# Epoch 1/20
# 1/1 [==============================] - 1s 872ms/step - loss: 0.3626 - mse: 0.3038 - cindex_score: 0.8673
# Epoch 2/20
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3653 - mse: 0.2884 - cindex_score: 0.8702
# Epoch 3/20
# 1/1 [==============================] - 1s 923ms/step - loss: 0.3436 - mse: 0.2726 - cindex_score: 0.8786
# Epoch 4/20
# 1/1 [==============================] - 1s 888ms/step - loss: 0.3489 - mse: 0.2741 - cindex_score: 0.8692
# Epoch 5/20
# 1/1 [==============================] - 0s 61ms/step - loss: 0.
20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2955 - mse: 0.2192 - cindex_score: 0.8749
# Epoch 18/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2997 - mse: 0.2128 - cindex_score: 0.8767
# Epoch 19/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2908 - mse: 0.1904 - cindex_score: 0.8839
# Epoch 20/20
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2881 - mse: 0.2193 - cindex_score: 0.8854
# 1/1 [==============================] - 0s 30ms/step
# [array([6.642916], dtype=float32), array([6.171094], dtype=float32), array([6.4237375], dtype=float32), array([6.5541396], dtype=float32), array([6.1057973], dtype=float32), array([5.9806123], dtype=float32), array([6.440834], dtype=float32), array([6.8407106], dtype=float32), array([6.198618], dtype=float32), array([6.096403], dtype=float32), array([6.1024914], dtype=float32), array([6.1829906], dtype=float32), array([5.90313], dtype=float32), array([6.682087], dtype=float32), array([7.093143], dtype=float32), array([7.0294704], dtype=float32), array([6.88855], dtype=float32), array([6.6597047], dtype=float32), array([7.1821365], dtype=float32), array([6.1957884], dtype=float32), array([6.8133326], dtype=float32), array([5.880401], dtype=float32), array([5.3339553], dtype=float32), array([6.783332], dtype=float32), array([6.073281], dtype=float32), array([6.2822766], dtype=float32), array([7.0016108], dtype=float32), array([6.3873396], dtype=float32), array([6.1470075], dtype=float32), array([6.1933227], dtype=float32), array([6.3088365], dtype=float32), array([7.141182], dtype=float32), array([6.172596], dtype=float32), array([6.3243437], dtype=float32), array([6.580884], dtype=float32), array([6.1456428], dtype=float32), array([6.048148], dtype=float32), array([6.85636], dtype=float32), array([6.4170356], dtype=float32), array([6.6076417], dtype=float32), array([6.0920463], dtype=float32), array([6.1221037], dtype=float32), array([6.589084], dtype=float32), array([6.146136], dtype=float32), array([6.3487673], dtype=float32), array([7.2762933], dtype=float32), array([6.464016], dtype=float32), array([6.7546678], dtype=float32), array([6.7489147], dtype=float32), array([6.571679], dtype=float32), array([6.121457], dtype=float32), array([5.6399226], dtype=float32), array([6.2143593], dtype=float32), array([6.6323676], dtype=float32), array([6.4545293], dtype=float32), array([6.7123013], dtype=float32), array([6.393948], dtype=float32), array([6.3397403], dtype=float32), array([6.424043], dtype=float32), array([6.376805], dtype=float32), array([7.183157], dtype=float32), array([6.0207686], dtype=float32), array([6.6584687], dtype=float32), array([6.487314], dtype=float32), array([6.793504], dtype=float32), array([6.346999], dtype=float32), array([6.0177393], dtype=float32), array([6.513209], dtype=float32), array([6.4208117], dtype=float32), array([6.8056407], dtype=float32), array([6.420172], dtype=float32), array([5.9067626], dtype=float32), array([6.1531205], dtype=float32), array([6.017228], dtype=float32), array([6.111235], dtype=float32), array([6.5352554], dtype=float32), array([6.4230714], dtype=float32), array([6.294594], dtype=float32), array([6.8967886], dtype=float32), array([6.13218], dtype=float32), array([6.67217], dtype=float32), array([6.275705], dtype=float32), array([6.037993], dtype=float32), array([5.9437943], dtype=float32)]
# MSE= 3.4573
# tf.Tensor(0.5539359, shape=(), dtype=float32)
